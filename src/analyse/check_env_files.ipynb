# %%
virus = "zika"
dist = 3
size = 10

# %%
import pandas as pd
import os

# %%
path = f"../../environments/{virus}/dist{dist}size{size}/"
files = os.listdir(path)

# %%
for file in files:
    # read parquet file
    df = pd.read_parquet(os.path.join(path, file))
    print("environment file name:", file, "\nshape:", df.shape)
    print()
    print(df.head(50))
    print("\n\n")
# Out:
# environment file name: lc_df.parquet
# shape: (1462, 4)
#
#                A.1  A.1.NmC1  A.1.NmC2  lc_pos
# 80_A|G       False     False      True      80
# 108_C|T      False     False      True     108
# 118_C|A      False     False      True     118
# 166_A|T      False      True      True     166
# 178_T|C       True      True      True     178
# 192_A|G       True      True      True     192
# 225_AC|GT     True      True      True     225
# 247_T|C       True      True      True     247
# 260_A|G       True      True      True     260
# 262_C|T       True      True      True     262
# 281_A|G       True      True      True     281
# 295_A|G       True      True      True     295
# 301_C|T       True      True      True     301
# 304_A|T       True      True      True     304
# 307_C|T       True      True      True     307
# 310_C|T       True      True      True     310
# 313_A|G       True      True      True     313
# 318_GGT|AAC   True      True      True     318
# 322_G|A       True      True      True     322
# 327_A|G       True      True      True     327
# 346_A|G       True      True      True     346
# 352_G|A       True      True      True     352
# 354_C|T       True      True      True     354
# 358_T|C       True      True      True     358
# 361_A|G       True      True      True     361
# 367_A|G       True      True      True     367
# 370_C|T       True      True      True     370
# 376_A|G       True      True      True     376
# 385_C|G       True      True      True     385
# 389_T|C       True      True      True     389
# 400_A|T       True      True      True     400
# 409_A|G       True      True      True     409
# 421_T|A       True      True      True     421
# 427_T|A       True      True      True     427
# 434_C|T       True      True      True     434
# 440_G|A       True      True      True     440
# 442_G|A       True      True      True     442
# 448_CC|TT     True      True      True     448
# 455_T|C       True      True      True     455
# 467_T|C       True      True      True     467
# 473_ACG|GTT   True      True      True     473
# 488_T|C       True      True      True     488
# 493_G|A       True      True      True     493
# 496_G|C       True      True      True     496
# 498_A|G       True      True      True     498
# 511_G|A       True      True      True     511
# 514_C|T       True      True      True     514
# 517_A|G       True      True      True     517
# 523_G|T       True      True      True     523
# 538_C|T       True      True      True     538
#
#
#
# environment file name: change_probability.parquet
# shape: (7609, 2)
#
#            probability  pos
# 7_.|C         0.000711    7
# 8_.|C         0.003554    8
# 12_T|G        0.003554   12
# 13_G|A        0.000711   13
# 14_T|G        0.000711   14
# 52_A|T        0.000711   52
# 52_A|G        0.001421   52
# 53_G|A        0.002843   53
# 57_A|G        0.000711   57
# 59_A|T        0.000711   59
# 60_A|G        0.002132   60
# 71_A|T        0.000711   71
# 71_A|C        0.000711   71
# 76_TT|GG      0.000711   76
# 76_T|G        0.000711   76
# 80_A|T        0.000711   80
# 80_A|G        0.180526   80
# 82_T|A        0.000711   82
# 83_CG|GT      0.000711   83
# 85_T|C        0.000711   85
# 87_C|A        0.000711   87
# 88_GT|AA      0.000711   88
# 88_G|T        0.004264   88
# 88_G|A        0.000711   88
# 89_T|C        0.000711   89
# 91_G|A        0.000711   91
# 97_T|C        0.000711   97
# 99_A|G        0.000711   99
# 100_G|C       0.000711  100
# 100           0.000711  100
# 104_G|A       0.000711  104
# 105_.|CG      0.000711  105
# 105_G|C       0.000711  105
# 108_CT|TC     0.000711  108
# 108_CT|TA     0.000711  108
# 108_C|T       0.172708  108
# 109_T|C       0.002132  109
# 110_G|T       0.000711  110
# 112           0.000711  112
# 112_C|A       0.001421  112
# 115_.|AG      0.001421  115
# 116_.|A       0.001421  116
# 116_A|C       0.015636  116
# 116_.|G       0.014925  116
# 117_AC|GA     0.003554  117
# 117_.|G       0.000711  117
# 117_AC|TA     0.007107  117
# 118_AC|TA     0.000711  118
# 118_C|T       0.004975  118
# 118_C|A       0.189765  118
#
#
#
# environment file name: change2lineage_probability.parquet
# shape: (7609, 4)
#
#                 A.1  A.1.NmC1  A.1.NmC2  pos
# 7_.|C      0.001198  0.000000  0.000000    7
# 8_.|C      0.005988  0.000000  0.000000    8
# 12_T|G     0.004790  0.000000  0.005128   12
# 13_G|A     0.000000  0.000000  0.005128   13
# 14_T|G     0.000000  0.000000  0.005128   14
# 52_A|G     0.000000  0.000000  0.010256   52
# 52_A|T     0.001198  0.000000  0.000000   52
# 53_G|A     0.001198  0.000000  0.015385   53
# 57_A|G     0.001198  0.000000  0.000000   57
# 59_A|T     0.001198  0.000000  0.000000   59
# 60_A|G     0.003593  0.000000  0.000000   60
# 71_A|C     0.001198  0.000000  0.000000   71
# 71_A|T     0.001198  0.000000  0.000000   71
# 76_T|G     0.001198  0.000000  0.000000   76
# 76_TT|GG   0.001198  0.000000  0.000000   76
# 80_A|G     0.041916  0.066313  0.994872   80
# 80_A|T     0.001198  0.000000  0.000000   80
# 82_T|A     0.001198  0.000000  0.000000   82
# 83_CG|GT   0.001198  0.000000  0.000000   83
# 85_T|C     0.001198  0.000000  0.000000   85
# 87_C|A     0.001198  0.000000  0.000000   87
# 88_GT|AA   0.001198  0.000000  0.000000   88
# 88_G|A     0.001198  0.000000  0.000000   88
# 88_G|T     0.007186  0.000000  0.000000   88
# 89_T|C     0.001198  0.000000  0.000000   89
# 91_G|A     0.001198  0.000000  0.000000   91
# 97_T|C     0.001198  0.000000  0.000000   97
# 99_A|G     0.000000  0.000000  0.005128   99
# 100_G|C    0.001198  0.000000  0.000000  100
# 100        0.001198  0.000000  0.000000  100
# 104_G|A    0.001198  0.000000  0.000000  104
# 105_G|C    0.001198  0.000000  0.000000  105
# 105_.|CG   0.001198  0.000000  0.000000  105
# 108_CT|TA  0.000000  0.000000  0.005128  108
# 108_C|T    0.032335  0.066313  0.979487  108
# 108_CT|TC  0.001198  0.000000  0.000000  108
# 109_T|C    0.003593  0.000000  0.000000  109
# 110_G|T    0.001198  0.000000  0.000000  110
# 112_C|A    0.002395  0.000000  0.000000  112
# 112        0.001198  0.000000  0.000000  112
# 115_.|AG   0.002395  0.000000  0.000000  115
# 116_A|C    0.017964  0.018568  0.000000  116
# 116_.|A    0.002395  0.000000  0.000000  116
# 116_.|G    0.025150  0.000000  0.000000  116
# 117_AC|GA  0.001198  0.000000  0.020513  117
# 117_AC|TA  0.011976  0.000000  0.000000  117
# 117_.|G    0.001198  0.000000  0.000000  117
# 118_.|A    0.001198  0.000000  0.000000  118
# 118_AC|TA  0.001198  0.000000  0.000000  118
# 118_C|T    0.008383  0.000000  0.000000  118
#
#
#
# environment file name: lc_quality_df.parquet
# shape: (1, 3)
#
#      A.1  A.1.NmC1  A.1.NmC2
# num  835       377       195
